# %% [markdown]
# ## 강화학습으로 미니카 학습 모델 생성 + 애니메이션 <== DQN사용
# MiniCar : (x, y, theta(방향각도), 속도)의 상태를 가짐, action은 3가지(좌회전, 직진, 우회전)
#
# 보상은 중앙에서 멀어질 수록 불이익. 목표에 도착시 보상 + 10, 도로 이탈 시 보상 -10
#
# 현재 정책학습은 main-model(Q-Network)이 담당, 안정적인 목표값 제공은 target-model이 담당
#
# 메모리 버퍼에 경험(state, action, ...)을 저장하고 샘플링하여 학습(경험을 재사용)

# %%
# !pip install gymnasium
# Out:
# Requirement already satisfied: gymnasium in /usr/local/lib/python3.12/dist-packages (1.3.0)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium) (2.0.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from gymnasium) (0.0.6)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import animation
from tensorflow import keras
from collections import deque
import random
import gymnasium as gym
from gymnasium import spaces

# %%
# 참고 : 각도 wrapping
def wrap_angle(theta):
  return (theta + np.pi) % (2 * np.pi) - np.pi

angle = np.deg2rad(370)   # 10
angle = np.deg2rad(-190)  # 170
angle = np.deg2rad(120)  # 120
print(np.rad2deg(wrap_angle(angle)))
# Out:
# 119.99999999999997

# %%
# 사용자 정의 환경
class MiniCarEnv(gym.Env):
    def __init__(self) -> None:
      super(MiniCarEnv, self).__init__()
      # 상태 공간
      self.observation_space = spaces.Box(
          low=np.array([0, 0, -np.pi, 0], dtype=np.float32),
          high=np.array([100, 100, np.pi, 100], dtype=np.float32)
      )
      # 행동 공간(action의 수) : 0-좌회전, 1-직진, 2-우회전
      self.action_space = spaces.Discrete(3)
      self.reset() # 오버라이딩

    def reset(self, seed=None, options=None):
      x = 10.0
      y = 50.0
      theta = 0.0
      v = 1.0
      self.state = np.array([x, y, theta, v])
      return self.state, {} # reset의 리턴값이 두개가 출력되어서 하나는 안받아도 됨 {}

    def step(self, action):
      x, y, theta, v = self.state.astype(np.float32)

      # 조향(좌,우회전) 갱신
      steer_step = 0.1
      if action == 0: # 왼쪽
        theta -= steer_step
      elif action == 2: # 오른쪽
        theta += steer_step

      theta  *= 0.98 # 조향 감쇠 : 자연스럽게 직진으로 돌아옴(과도한 회전 억제)

      # 각도 wrapping : 각도를 항상 [-𝝅, +𝝅](-180도 , 180도) 범위 안에 맞추기 - 각도 정규화
      theta = (theta + np.pi) % (2 * np.pi) - np.pi

      # 이동 - 2차원 좌표 상에서
      # x축 이동량 : x = x + v * cos(theta)
      # y축 이동량 : y = y + v * sin(theta)
      n = np.random.normal(0, 0.02, size=2) # 강화학습의 반영할 noise(센서오차, 바람, 미끄러짐 ...)
      x_prev = x # 원래 x값 - x값에 변화를 주기위해 담아두기
      x = x + v * np.cos(theta) + n[0]
      y = y + v * np.sin(theta) + n[1]

      self.state = np.array([x, y, theta, v], dtype=np.float32) # 상태 update

      # 보상에 대한 설계
      # 중앙선에서 벗어나면 패널티를 부여(감점 고려)
      center_penalty = -0.05 * abs(y - 50.00)
      # 진행 보상 : 직진 한 만큼 보상 (뒤/옆 이동 억제)
      process = max(0.0, x - x_prev) * 0.8
      # 생존 보상 - 너무 크면 좋지 않다.(1.0 과해)
      alive = 0.2

      reward = alive + process + center_penalty # 전체 보상

      # 종료 조건
      terminated = False
      truncated = False

      if x > 90 and 0 <= y <= 100: # 목표 달성
        reward += 50.0
        terminated = True
      elif not(0 <= x <= 100 and 0 <= y <= 100): # 도로 이탈
        reward -= 15.0
        terminated = True

      return self.state, float(reward), terminated, truncated, {}

# %%
# DQN 모델 생성
def create_dqn(input_dim, output_dim):
    model = keras.Sequential([
        keras.layers.Input(shape=(input_dim,)),
        keras.layers.Dense(64, activation='relu'),
        keras.layers.Dense(64, activation='relu'),
        keras.layers.Dense(output_dim, activation='linear')
    ])
    model.compile(optimizer=keras.optimizers.Adam(learning_rate = 0.001), loss='mse')
    return model

# 실험 값 설정 하기
episodes = 100
runs = 1    # 전체 학습을 몇번 반복할 지 설정 2 ~ 3을 권장

all_run_rewards = []    # 에피소드별 총 보상 저장
all_run_deviations = [] # 도로 중앙(y=50)으로 부터 평균 편차 저장
final_trajectorie = []  # 에피소드별 이동 경로 저장 - 애니메이션

# 학습 하기. - 강화 학습의 특성(무작위)상 여러번 실행해 평균 성능을 확인하길 권장
for run in range(runs):
    env = MiniCarEnv()
    state_dim = env.observation_space.shape[0] # 관측 차원 수 : 4
    num_actions = int(env.action_space.n) # 가능한 행동 수 :3

    # model : 현재 Q값을 예측하고 학습하는 신경망 모델
    # target model : 비교 기준이 되는 고정된 Q값을 제공(학습 목표값 계산에 사용)
    model = create_dqn(state_dim, num_actions) # 메인모델(메인 네트워크)
    target_model = create_dqn(state_dim, num_actions) # 타겟모델(타겟 네트워크)
    target_model.set_weights(model.get_weights())


    # 하이퍼 파라미터 설정
    gamma = 0.99
    epsilon = 0.6
    epsilon_decay = 0.997
    epsilon_min = 0.02

    batch_size = 32 # 미니배치값 - 경험을 32개씩 샘플링해서 학습
    memory = deque(maxlen=2000) # ReplayBuffer 크기 - 2000개가 싸이면 32개씩 뽑아서 샘플링 진행

    reward_history = [] # 에피소드 마다 받은 총 보상을 저장
    deviation_history = [] # 주행 중 y값이 도로 중심에서 얼마나 벗어났는지 평균 편차 저장
    run_trajectories = []
    CENTER_Y = 50.0 # 도로 중앙선 기준값

    for ep in range(episodes):
      state, _ = env.reset()
      print(f'Run {run} 에피소드 시작 : ep = {ep}, 초기 상태 = {state}')

      total_reward = 0
      trajectory = []
      done = False

      for step in range(200): # 하나의 에피소드에서 200번의 행동을 함
        state_input = np.reshape(state, [1, state_dim]) # 1차원을 -> 2차원으로 확대(신경망에 넣기 위해)

        # 탐험, 이용 결정
        if np.random.rand() < epsilon:
          action = np.random.choice(num_actions)
        else:
          q_values = model.predict(state_input, verbose=0) # 모든 행동에서의 q값
          action = np.argmax(q_values[0])

        # 행동 실행
        next_state, reward, done, _, _ = env.step(action)

        # 경험 저장
        memory.append((state, action, reward, next_state, done))

        # 경로 및 보상 누적
        trajectory.append(state)
        total_reward += reward

        state = next_state
        if done: break

      # 하나의 에피소드가 끝난 뒤, 그 동안의 성과(보상, 이동경로, 편차 등)를 기록
      reward_history.append(total_reward)
      traj = np.array(trajectory) # 이동 경로 배열로 변환(벡터 연산이 가능해짐 - 편차 계산하기 위해)
      mean_deviation = np.mean(np.abs(traj[:, 1] - CENTER_Y)) # 이동 경로의 평균 편차 계산

      deviation_history.append(mean_deviation) # 에피소드 평균 편차 저장 - 그래프 출력용
      run_trajectories.append((ep, trajectory.copy())) # 이동경로 저장
      print(f'Run {run} 에피소드 종료 : ep = {ep}, 총 보상 = {total_reward}, 평균 편차 = {mean_deviation}, 종료상태 = {state}')

      # 메모리에서 무작위 샘플링 후 Q-Network(MainNetwork) 갱신
      if len(memory) >= batch_size:
        minibatch = random.sample(memory, batch_size)

        states, targets = [], [] # 학습에 사용 할 입력(states)과 목표 값(targets) 누적용

        # 각 샘플에 대해 Q값 계산
        for state, action, reward, next_state, done in minibatch:
          s_input = np.reshape(state, [1, state_dim])
          s_next_input = np.reshape(next_state, [1, state_dim])

          target = model.predict(s_input, verbose=0)[0] # 현재상태(state) 에서 각 행동의 Q값 예측

          if done:
            target[action] = reward # 종료된 상태면 단순히 reward가 정답이 됨
          else:
            # DQN 핵심!!
            t_next = target_model.predict(s_next_input, verbose=0)[0] # Target Model로 다음 상태의 Q값 예측
            # 벨만 방정식 적용 - 정책 개선
            target[action] = reward + gamma * np.max(t_next)

          # 학습 입력/타겟 누적
          states.append(s_input[0])
          targets.append(target)

        # Q-Network 학습 - 메인 모델 학습
        model.fit(np.array(states), np.array(targets), epochs=1, verbose=0) # 강화 학습 - epoch=1줌

      if epsilon > epsilon_min:
        epsilon *= epsilon_decay

      if ep % 10 == 0: # target network 갱신
        target_model.set_weights(model.get_weights())

    # 하나의 run안에서 각 에피소드별 보상
    all_run_rewards.append(reward_history)
    #하나의 run안에서 각 에피소드별 표준편차
    all_run_deviations.append(deviation_history)
    # 마지막 run의 경로데이터 저장
    if run == runs - 1:
      final_trajectorie = run_trajectories
# Out:
# Run 0 에피소드 시작 : ep = 0, 초기 상태 = [10. 50.  0.  1.]
# Run 0 에피소드 종료 : ep = 0, 총 보상 = 100.74926454518047, 평균 편차 = 6.9901315620146605, 종료상태 = [90.08573    31.794628   -0.22372746  1.        ]
# Run 0 에피소드 시작 : ep = 1, 초기 상태 = [10. 50.  0.  1.]
# Run 0 에피소드 종료 : ep = 1, 총 보상 = 125.75840345103333, 평균 편차 = 1.2599664083341273, 종료상태 = [90.737686   48.682507   -0.46790504  1.        ]
# Run 0 에피소드 시작 : ep = 2, 초기 상태 = [10. 50.  0.  1.]
# Run 0 에피소드 종료 : ep = 2, 총 보상 = 112.62607906067782, 평균 편차 = 4.224948129536193, 종료상태 = [90.022644   59.62032     0.10197759  1.        ]
# Run 0 에피소드 시작 : ep = 3, 초기 상태 = [10. 50.  0.  1.]
# Run 0 에피소드 종료 : ep = 3, 총 보상 = 85.18319365738013, 평균 편차 = 10.193723339504666, 종료상태 = [90.79615   81.6391     0.6227782  1.       ]
# Run 0 에피소드 시작 : ep = 4, 초기 상태 = [10. 50.  0.  1.]
# Run 0 에피소드 종료 : ep = 4, 총 보상 = 94.35182451714832, 평균 편차 = 8.59022016410368, 종료상태 = [90.25974    66.13104     0.17036557  1.        ]
# Run 0 에피소드 시작 : ep = 5, 초기 상태 = [10. 50.  0.  1.]
# Run 0 에피소드 종료 : ep = 5, 총 보상 = 122.32183913486811, 평균 편차 = 2.134562855675107, 종료상태 = [90.727905  48.093575  -0.7550292  1.       ]
# Run 0 에피소드 시작 : ep = 6, 초기 상태 = [10. 50.  0.  1.]
# Run 0 에피소드 종료 : ep = 6, 총 보상 = -34.58317069664052, 평균 편차 = 20.20951430242637, 종료상태 = [76.83288    -0.76204747 -1.1495713   1.        ]
# Run 0 에피소드 시작 : ep = 7, 초기 상태 = [10. 50.  0.  1.]
# Run 0 에피소드 종료 : ep = 7, 총 보상 = 110.31742331707913, 평균 편차 = 4.689288139343262, 종료상태 = [90.08696   38.371655  -1.4706784  1.       ]
# Run 0 에피소드 시작 : ep = 8, 초기 상태 = [10. 50.  0.  1.]
# Run 0 에피소드 종료 : ep = 8, 총 보상 = -2.6198854110278305, 평균 편차 = 12.300051453812369, 종료상태 = [87.27828   -0.519822  -1.2830542  1.       ]
# Run 0 에피소드 시작 : ep = 9, 초기 상태 = [10. 50.  0.  1.]
# Run 0 에피소드 종료 : ep = 9, 총 보상 = -19.737844968220234, 평균 편차 = 13.612028816676869, 종료상태 = [64.81908   -0.9578044 -1.7044592  1.       ]
# Run 0 에피소드 시작 : ep = 10, 초기 상태 = [10. 50.  0.  1.]
# Run 0 에피소드 종료 : ep = 10, 총 보상 = -40.5875265696523, 평균 편차 = 18.509883244832356, 종료상태 = [ 45.879726  100.27136     1.7076156   1.       ]
# Run 0 에피소드 시작 : ep = 11, 초기 상태 = [10. 50.  0.  1.]
# Run 0 에피소드 종료 : ep = 11, 총 보상 = -52.67329472619835, 평균 편차 = 20.99687805175781, 종료상태 = [ 28.466785 100.08965    1.636914   1.      ]
# Run 0 에피소드 시작 : ep = 12, 초기 상태 = [10. 50.  0.  1.]
# Run 0 에피소드 종료 : ep = 12, 총 보상 = -40.813437459686526, 평균 편차 = 19.72076940536499, 종료상태 = [ 51.627415  100.41198     1.4275124   1.       ]
# Run 0 에피소드 시작 : ep = 13, 초기 상태 = [10. 50.  0.  1.]
# Run 0 에피소드 종료 : ep = 13, 총 보상 = -45.89987146561714, 평균 편차 = 19.965172098643745, 종료상태 = [ 39.35872   100.271706    1.7797778   1.       ]
# Run 0 에피소드 시작 : ep = 14, 초기 상태 = [10. 50.  0.  1.]
# Run 0 에피소드 종료 : ep = 14, 총 보상 = -52.76360852499387, 평균 편차 = 21.33114747078188, 종료상태 = [ 31.13749   100.747574    1.9246328   1.       ]
# Run 0 에피소드 시작 : ep = 15, 초기 상태 = [10. 50.  0.  1.]
# Run 0 에피소드 종료 : ep = 15, 총 보상 = -45.520761256117005, 평균 편차 = 21.468912740854115, 종료상태 = [ 45.94242  100.0146     1.348737   1.      ]
# Run 0 에피소드 시작 : ep = 16, 초기 상태 = [10. 50.  0.  1.]
# Run 0 에피소드 종료 : ep = 16, 총 보상 = -41.997558757270454, 평균 편차 = 18.954214586530412, 종료상태 = [ 43.66909   100.61351     1.9197514   1.       ]
# Run 0 에피소드 시작 : ep = 17, 초기 상태 = [10. 50.  0.  1.]
# Run 0 에피소드 종료 : ep = 17, 총 보상 = 58.466925533777044, 평균 편차 = 13.839471357840079, 종료상태 = [90.11856   99.91846    0.9464166  1.       ]
# Run 0 에피소드 시작 : ep = 18, 초기 상태 = [10. 50.  0.  1.]
# Run 0 에피소드 종료 : ep = 18, 총 보상 = 95.80715222441634, 평균 편차 = 7.879961880770597, 종료상태 = [90.072975  73.58805    1.0722058  1.       ]
# Run 0 에피소드 시작 : ep = 19, 초기 상태 = [10. 50.  0.  1.]
# Run 0 에피소드 종료 : ep = 19, 총 보상 = 102.40852745052138, 평균 편차 = 6.739619473376906, 종료상태 = [90.73947   66.271996   0.2639389  1.       ]
# Run 0 에피소드 시작 : ep = 20, 초기 상태 = [10. 50.  0.  1.]
# Run 0 에피소드 종료 : ep = 20, 총 보상 = 124.89297314874041, 평균 편차 = 1.321589872061488, 종료상태 = [90.08808   55.85807    0.7699554  1.       ]
# Run 0 에피소드 시작 : ep = 21, 초기 상태 = [10. 50.  0.  1.]
# Run 0 에피소드 종료 : ep = 21, 총 보상 = 126.30110082318163, 평균 편차 = 0.9778448895710271, 종료상태 = [90.105415   53.481216    0.72588325  1.        ]
# Run 0 에피소드 시작 : ep = 22, 초기 상태 = [10. 50.  0.  1.]
# Run 0 에피소드 종료 : ep = 22, 총 보상 = 114.2661937649404, 평균 편차 = 3.7926261992681596, 종료상태 = [90.133316   35.77139    -0.59324765  1.        ]
# Run 0 에피소드 시작 : ep = 23, 초기 상태 = [10. 50.  0.  1.]
# Run 0 에피소드 종료 : ep = 23, 총 보상 = 120.08911476498383, 평균 편차 = 2.4721827219767745, 종료상태 = [90.38465    38.819176   -0.96316504  1.        ]
# Run 0 에피소드 시작 : ep = 24, 초기 상태 = [10. 50.  0.  1.]
# Run 0 에피소드 종료 : ep = 24, 총 보상 = 54.20390484420671, 평균 편차 = 16.591979151186734, 종료상태 = [90.21064    90.83021     0.52175784  1.        ]
# Run 0 에피소드 시작 : ep = 25, 초기 상태 = [10. 50.  0.  1.]
# Run 0 에피소드 종료 : ep = 25, 총 보상 = 88.4245723122056, 평균 편차 = 9.870917510986327, 종료상태 = [90.76872    74.780655    0.38581228  1.        ]
# Run 0 에피소드 시작 : ep = 26, 초기 상태 = [10. 50.  0.  1.]
# Run 0 에피소드 종료 : ep = 26, 총 보상 = -42.665290885892894, 평균 편차 = 20.7925399394942, 종료상태 = [52.986546   -0.20580336 -0.7497673   1.        ]
# Run 0 에피소드 시작 : ep = 27, 초기 상태 = [10. 50.  0.  1.]
# Run 0 에피소드 종료 : ep = 27, 총 보상 = -45.02021498187465, 평균 편차 = 21.789365033893024, 종료상태 = [51.22369    -0.30651352 -0.8767569   1.        ]
# Run 0 에피소드 시작 : ep = 28, 초기 상태 = [10. 50.  0.  1.]
# Run 0 에피소드 종료 : ep = 28, 총 보상 = -22.227740065145987, 평균 편차 = 29.36352523317877, 종료상태 = [90.043205  13.287893   0.8065536  1.       ]
# Run 0 에피소드 시작 : ep = 29, 초기 상태 = [10. 50.  0.  1.]
# Run 0 에피소드 종료 : ep = 29, 총 보상 = -47.441074631202454, 평균 편차 = 21.810488143610577, 종료상태 = [42.709923  -0.1196569 -1.1362522  1.       ]
# Run 0 에피소드 시작 : ep = 30, 초기 상태 = [10. 50.  0.  1.]
# Run 0 에피소드 종료 : ep = 30, 총 보상 = -42.68337031866939, 평균 편차 = 19.535973998052732, 종료상태 = [46.08355   -0.4508445 -1.154745   1.       ]
# Run 0 에피소드 시작 : ep = 31, 초기 상태 = [10. 50.  0.  1.]
# Run 0 에피소드 종료 : ep = 31, 총 보상 = -43.427648007326866, 평균 편차 = 19.624600239310947, 종료상태 = [44.62124   -0.6547462 -1.1122756  1.       ]
# Run 0 에피소드 시작 : ep = 32, 초기 상태 = [10. 50.  0.  1.]
# Run 0 에피소드 종료 : ep = 32, 총 보상 = -53.839719706013504, 평균 편차 = 21.573146749536196, 종료상태 = [29.321236  -0.6179215 -1.2463738  1.       ]
# Run 0 에피소드 시작 : ep = 33, 초기 상태 = [10. 50.  0.  1.]
# Run 0 에피소드 종료 : ep = 33, 총 보상 = -3.783259899172677, 평균 편차 = 26.600634061017082, 종료상태 = [90.19078    19.147505    0.52869296  1.        ]
# Run 0 에피소드 시작 : ep = 34, 초기 상태 = [10. 50.  0.  1.]
# Run 0 에피소드 종료 : ep = 34, 총 보상 = 11.487867108453834, 평균 편차 = 18.944152893779947, 종료상태 = [90.48446   62.543354   0.9505513  1.       ]
# Run 0 에피소드 시작 : ep = 35, 초기 상태 = [10. 50.  0.  1.]
# Run 0 에피소드 종료 : ep = 35, 총 보상 = 60.917869216036124, 평균 편차 = 12.599785507702437, 종료상태 = [90.38486    68.65561     0.82157636  1.        ]
# Run 0 에피소드 시작 : ep = 36, 초기 상태 = [10. 50.  0.  1.]
# Run 0 에피소드 종료 : ep = 36, 총 보상 = 105.19499907105177, 평균 편차 = 6.145672074283462, 종료상태 = [90.630005   58.089256    0.23194647  1.        ]
# Run 0 에피소드 시작 : ep = 37, 초기 상태 = [10. 50.  0.  1.]
# Run 0 에피소드 종료 : ep = 37, 총 보상 = 112.5417626700229, 평균 편차 = 4.456118629092262, 종료상태 = [90.68776    48.14498     0.43736744  1.        ]
# Run 0 에피소드 시작 : ep = 38, 초기 상태 = [10. 50.  0.  1.]
# Run 0 에피소드 종료 : ep = 38, 총 보상 = 123.01095835461675, 평균 편차 = 1.9115286677716725, 종료상태 = [90.73728   54.920444   0.6003132  1.       ]
# Run 0 에피소드 시작 : ep = 39, 초기 상태 = [10. 50.  0.  1.]
# Run 0 에피소드 종료 : ep = 39, 총 보상 = 91.35458293979346, 평균 편차 = 8.166581284766103, 종료상태 = [90.147156  80.271324   0.8377571  1.       ]
# Run 0 에피소드 시작 : ep = 40, 초기 상태 = [10. 50.  0.  1.]
# Run 0 에피소드 종료 : ep = 40, 총 보상 = 100.4870144133723, 평균 편차 = 6.440085953357173, 종료상태 = [90.078835  72.631836   1.1711943  1.       ]
# Run 0 에피소드 시작 : ep = 41, 초기 상태 = [10. 50.  0.  1.]
# Run 0 에피소드 종료 : ep = 41, 총 보상 = 98.21547483410103, 평균 편차 = 7.6086372927010775, 종료상태 = [90.196625  69.319855   0.3992834  1.       ]
# Run 0 에피소드 시작 : ep = 42, 초기 상태 = [10. 50.  0.  1.]
# Run 0 에피소드 종료 : ep = 42, 총 보상 = 91.39800830241961, 평균 편차 = 9.336767787025089, 종료상태 = [90.44868    39.069782    0.43130684  1.        ]
# Run 0 에피소드 시작 : ep = 43, 초기 상태 = [10. 50.  0.  1.]
# Run 0 에피소드 종료 : ep = 43, 총 보상 = 122.50175362378202, 평균 편차 = 1.9545727465526168, 종료상태 = [90.618706   59.634594    0.40069413  1.        ]
# Run 0 에피소드 시작 : ep = 44, 초기 상태 = [10. 50.  0.  1.]
# Run 0 에피소드 종료 : ep = 44, 총 보상 = 95.10638004941214, 평균 편차 = 7.648502581047289, 종료상태 = [90.07251   67.830894   1.1219108  1.       ]
# Run 0 에피소드 시작 : ep = 45, 초기 상태 = [10. 50.  0.  1.]
# Run 0 에피소드 종료 : ep = 45, 총 보상 = 109.7369955834834, 평균 편차 = 4.652444578471937, 종료상태 = [90.20255   76.518875   1.1558564  1.       ]
# Run 0 에피소드 시작 : ep = 46, 초기 상태 = [10. 50.  0.  1.]
# Run 0 에피소드 종료 : ep = 46, 총 보상 = 96.61516981349847, 평균 편차 = 6.9312055712548375, 종료상태 = [90.18208   86.97114    1.2103841  1.       ]
# Run 0 에피소드 시작 : ep = 47, 초기 상태 = [10. 50.  0.  1.]
# Run 0 에피소드 종료 : ep = 47, 총 보상 = 96.04926945695857, 평균 편차 = 7.430159432547433, 종료상태 = [90.04013   73.50126    1.3014615  1.       ]
# Run 0 에피소드 시작 : ep = 48, 초기 상태 = [10. 50.  0.  1.]
# Run 0 에피소드 종료 : ep = 48, 총 보상 = 121.26210583294711, 평균 편차 = 2.2789576886648155, 종료상태 = [90.18701    49.403423    0.60856867  1.        ]
# Run 0 에피소드 시작 : ep = 49, 초기 상태 = [10. 50.  0.  1.]
# Run 0 에피소드 종료 : ep = 49, 총 보상 = 108.78950034714278, 평균 편차 = 5.342195510864258, 종료상태 = [90.651924   54.58036    -0.09549809  1.        ]
# Run 0 에피소드 시작 : ep = 50, 초기 상태 = [10. 50.  0.  1.]
# Run 0 에피소드 종료 : ep = 50, 총 보상 = 103.00231421398325, 평균 편차 = 6.658599761595209, 종료상태 = [90.92832    64.14296     0.20883512  1.        ]
# Run 0 에피소드 시작 : ep = 51, 초기 상태 = [10. 50.  0.  1.]
# Run 0 에피소드 종료 : ep = 51, 총 보상 = 123.69526644038939, 평균 편차 = 1.6674073382121761, 종료상태 = [ 9.0307953e+01  4.7705929e+01 -4.9218893e-02  1.0000000e+00]
# Run 0 에피소드 시작 : ep = 52, 초기 상태 = [10. 50.  0.  1.]
# Run 0 에피소드 종료 : ep = 52, 총 보상 = 116.61999831293559, 평균 편차 = 3.2820310360047875, 종료상태 = [90.244415   60.384315    0.18520188  1.        ]
# Run 0 에피소드 시작 : ep = 53, 초기 상태 = [10. 50.  0.  1.]
# Run 0 에피소드 종료 : ep = 53, 총 보상 = 122.69012347317563, 평균 편차 = 1.8719529045952692, 종료상태 = [90.21854    47.933838   -0.15259147  1.        ]
# Run 0 에피소드 시작 : ep = 54, 초기 상태 = [10. 50.  0.  1.]
# Run 0 에피소드 종료 : ep = 54, 총 보상 = 112.03089885989729, 평균 편차 = 4.315706143434021, 종료상태 = [90.56404   29.05976   -0.8431134  1.       ]
# Run 0 에피소드 시작 : ep = 55, 초기 상태 = [10. 50.  0.  1.]
# Run 0 에피소드 종료 : ep = 55, 총 보상 = 93.70508700003546, 평균 편차 = 8.571260043552943, 종료상태 = [90.00083   71.92566    0.5439894  1.       ]
# Run 0 에피소드 시작 : ep = 56, 초기 상태 = [10. 50.  0.  1.]
# Run 0 에피소드 종료 : ep = 56, 총 보상 = -17.405280616534153, 평균 편차 = 15.65803378790617, 종료상태 = [83.01251    -0.50301814 -0.9443052   1.        ]
# Run 0 에피소드 시작 : ep = 57, 초기 상태 = [10. 50.  0.  1.]
# Run 0 에피소드 종료 : ep = 57, 총 보상 = -15.523948649102268, 평균 편차 = 14.545033589917786, 종료상태 = [77.07154    -0.21015368 -1.1929086   1.        ]
# Run 0 에피소드 시작 : ep = 58, 초기 상태 = [10. 50.  0.  1.]
# Run 0 에피소드 종료 : ep = 58, 총 보상 = -34.58911141200045, 평균 편차 = 17.23131693013107, 종료상태 = [53.828808  -0.558997  -1.2440877  1.       ]
# Run 0 에피소드 시작 : ep = 59, 초기 상태 = [10. 50.  0.  1.]
# Run 0 에피소드 종료 : ep = 59, 총 보상 = -39.55043419922069, 평균 편차 = 19.16748625375855, 종료상태 = [49.700214   -0.34849527 -1.5027149   1.        ]
# Run 0 에피소드 시작 : ep = 60, 초기 상태 = [10. 50.  0.  1.]
# Run 0 에피소드 종료 : ep = 60, 총 보상 = -38.6105425082367, 평균 편차 = 18.2879287258784, 종료상태 = [48.52605    -0.24671258 -1.8921769   1.        ]
# Run 0 에피소드 시작 : ep = 61, 초기 상태 = [10. 50.  0.  1.]
# Run 0 에피소드 종료 : ep = 61, 총 보상 = -47.90827036808756, 평균 편차 = 19.43866866646391, 종료상태 = [34.768845   -0.46536508 -1.6401161   1.        ]
# Run 0 에피소드 시작 : ep = 62, 초기 상태 = [10. 50.  0.  1.]
# Run 0 에피소드 종료 : ep = 62, 총 보상 = -58.94664520200271, 평균 편차 = 19.56072380564299, 종료상태 = [16.276089   -0.44874755 -2.316303    1.        ]
# Run 0 에피소드 시작 : ep = 63, 초기 상태 = [10. 50.  0.  1.]
# Run 0 에피소드 종료 : ep = 63, 총 보상 = -44.22836413576179, 평균 편차 = 20.092433831613995, 종료상태 = [45.63348   -0.867285  -1.7561977  1.       ]
# Run 0 에피소드 시작 : ep = 64, 초기 상태 = [10. 50.  0.  1.]
# Run 0 에피소드 종료 : ep = 64, 총 보상 = -8.955005276876209, 평균 편차 = 13.737825263323991, 종료상태 = [90.68946    -0.28198752 -0.68028927  1.        ]
# Run 0 에피소드 시작 : ep = 65, 초기 상태 = [10. 50.  0.  1.]
# Run 0 에피소드 종료 : ep = 65, 총 보상 = -9.411982594013391, 평균 편차 = 12.773580980480165, 종료상태 = [83.556526   -0.1418837  -0.92368627  1.        ]
# Run 0 에피소드 시작 : ep = 66, 초기 상태 = [10. 50.  0.  1.]
# Run 0 에피소드 종료 : ep = 66, 총 보상 = 122.86697176823029, 평균 편차 = 1.9214602811836903, 종료상태 = [ 9.0617897e+01  4.9091526e+01 -8.0653906e-02  1.0000000e+00]
# Run 0 에피소드 시작 : ep = 67, 초기 상태 = [10. 50.  0.  1.]
# Run 0 에피소드 종료 : ep = 67, 총 보상 = 108.48213755002584, 평균 편차 = 5.2913295931932405, 종료상태 = [90.27607    41.114346    0.09068632  1.        ]
# Run 0 에피소드 시작 : ep = 68, 초기 상태 = [10. 50.  0.  1.]
# Run 0 에피소드 종료 : ep = 68, 총 보상 = 125.5298682899456, 평균 편차 = 1.258867711196711, 종료상태 = [90.606094   51.13152    -0.12120509  1.        ]
# Run 0 에피소드 시작 : ep = 69, 초기 상태 = [10. 50.  0.  1.]
# Run 0 에피소드 종료 : ep = 69, 총 보상 = 107.87987488151393, 평균 편차 = 5.381801559264401, 종료상태 = [90.55026   33.483097  -0.5561652  1.       ]
# Run 0 에피소드 시작 : ep = 70, 초기 상태 = [10. 50.  0.  1.]
# Run 0 에피소드 종료 : ep = 70, 총 보상 = 47.941962513147736, 평균 편차 = 18.75418576327237, 종료상태 = [9.0564125e+01 8.1818794e+01 3.1425238e-02 1.0000000e+00]
# Run 0 에피소드 시작 : ep = 71, 초기 상태 = [10. 50.  0.  1.]
# Run 0 에피소드 종료 : ep = 71, 총 보상 = -51.855330704749804, 평균 편차 = 20.81406371824203, 종료상태 = [ 28.473381 100.157745   1.677479   1.      ]
# Run 0 에피소드 시작 : ep = 72, 초기 상태 = [10. 50.  0.  1.]
# Run 0 에피소드 종료 : ep = 72, 총 보상 = -47.282796487289275, 평균 편차 = 20.145299010806614, 종료상태 = [ 38.25266   100.24949     2.4115155   1.       ]
# Run 0 에피소드 시작 : ep = 73, 초기 상태 = [10. 50.  0.  1.]
# Run 0 에피소드 종료 : ep = 73, 총 보상 = -53.61051295586694, 평균 편차 = 20.87145305815197, 종료상태 = [ 26.622753  100.18651     2.2128747   1.       ]
# Run 0 에피소드 시작 : ep = 74, 초기 상태 = [10. 50.  0.  1.]
# Run 0 에피소드 종료 : ep = 74, 총 보상 = -41.208178200691364, 평균 편차 = 18.352311905116252, 종료상태 = [ 44.087795  100.55919     1.7481058   1.       ]
# Run 0 에피소드 시작 : ep = 75, 초기 상태 = [10. 50.  0.  1.]
# Run 0 에피소드 종료 : ep = 75, 총 보상 = -55.67803609684966, 평균 편차 = 21.205509310863057, 종료상태 = [ 23.903854  100.658394    1.8106711   1.       ]
# Run 0 에피소드 시작 : ep = 76, 초기 상태 = [10. 50.  0.  1.]
# Run 0 에피소드 종료 : ep = 76, 총 보상 = -44.096812017004126, 평균 편차 = 20.80201317282284, 종료상태 = [ 47.370354  100.47049     1.8011105   1.       ]
# Run 0 에피소드 시작 : ep = 77, 초기 상태 = [10. 50.  0.  1.]
# Run 0 에피소드 종료 : ep = 77, 총 보상 = -45.629843006566176, 평균 편차 = 21.307279124404445, 종료상태 = [ 46.265175  100.55929     1.4378932   1.       ]
# Run 0 에피소드 시작 : ep = 78, 초기 상태 = [10. 50.  0.  1.]
# Run 0 에피소드 종료 : ep = 78, 총 보상 = -52.75332123565833, 평균 편차 = 20.946651169748016, 종료상태 = [ 27.18616  100.49866    2.140175   1.      ]
# Run 0 에피소드 시작 : ep = 79, 초기 상태 = [10. 50.  0.  1.]
# Run 0 에피소드 종료 : ep = 79, 총 보상 = -31.792321220831486, 평균 편차 = 17.48812051027654, 종료상태 = [60.107418  -0.5817829 -2.054249   1.       ]
# Run 0 에피소드 시작 : ep = 80, 초기 상태 = [10. 50.  0.  1.]
# Run 0 에피소드 종료 : ep = 80, 총 보상 = -34.72859372237996, 평균 편차 = 17.241470075272893, 종료상태 = [ 5.0028419e+01 -1.9489188e-02 -1.8948619e+00  1.0000000e+00]
# Run 0 에피소드 시작 : ep = 81, 초기 상태 = [10. 50.  0.  1.]
# Run 0 에피소드 종료 : ep = 81, 총 보상 = -29.57539789390805, 평균 편차 = 16.097235025361528, 종료상태 = [57.771324   -0.38938913 -1.5603242   1.        ]
# Run 0 에피소드 시작 : ep = 82, 초기 상태 = [10. 50.  0.  1.]
# Run 0 에피소드 종료 : ep = 82, 총 보상 = -3.604142379962113, 평균 편차 = 11.849820626087677, 종료상태 = [79.25512    -0.10241815 -1.802475    1.        ]
# Run 0 에피소드 시작 : ep = 83, 초기 상태 = [10. 50.  0.  1.]
# Run 0 에피소드 종료 : ep = 83, 총 보상 = 119.4131884802325, 평균 편차 = 2.642862180384194, 종료상태 = [90.41327    59.633568    0.19678855  1.        ]
# Run 0 에피소드 시작 : ep = 84, 초기 상태 = [10. 50.  0.  1.]
# Run 0 에피소드 종료 : ep = 84, 총 보상 = 117.75361009153323, 평균 편차 = 3.1062406375084395, 종료상태 = [90.174995   50.121964   -0.10522413  1.        ]
# Run 0 에피소드 시작 : ep = 85, 초기 상태 = [10. 50.  0.  1.]
# Run 0 에피소드 종료 : ep = 85, 총 보상 = 125.4442476125274, 평균 편차 = 1.2385261441454476, 종료상태 = [90.35317   50.445034   0.1871512  1.       ]
# Run 0 에피소드 시작 : ep = 86, 초기 상태 = [10. 50.  0.  1.]
# Run 0 에피소드 종료 : ep = 86, 총 보상 = 119.98897319376768, 평균 편차 = 2.45798831515842, 종료상태 = [ 9.0024429e+01  5.5514294e+01 -1.5872240e-02  1.0000000e+00]
# Run 0 에피소드 시작 : ep = 87, 초기 상태 = [10. 50.  0.  1.]
# Run 0 에피소드 종료 : ep = 87, 총 보상 = 95.60769047587296, 평균 편차 = 7.964461109854958, 종료상태 = [90.47197   23.47475   -0.8240001  1.       ]
# Run 0 에피소드 시작 : ep = 88, 초기 상태 = [10. 50.  0.  1.]
# Run 0 에피소드 종료 : ep = 88, 총 보상 = 81.37390806858707, 평균 편차 = 11.53942802974156, 종료상태 = [90.22888    72.87222     0.22157288  1.        ]
# Run 0 에피소드 시작 : ep = 89, 초기 상태 = [10. 50.  0.  1.]
# Run 0 에피소드 종료 : ep = 89, 총 보상 = 102.51678326496693, 평균 편차 = 6.165831355044716, 종료상태 = [90.24843    22.114927   -0.93310976  1.        ]
# Run 0 에피소드 시작 : ep = 90, 초기 상태 = [10. 50.  0.  1.]
# Run 0 에피소드 종료 : ep = 90, 총 보상 = -25.30451601831763, 평균 편차 = 15.51467409854134, 종료상태 = [63.82841    -0.35832295 -2.5261242   1.        ]
# Run 0 에피소드 시작 : ep = 91, 초기 상태 = [10. 50.  0.  1.]
# Run 0 에피소드 종료 : ep = 91, 총 보상 = -18.520073839944267, 평균 편차 = 13.031774068420583, 종료상태 = [64.41983    -0.43772796 -1.7458384   1.        ]
# Run 0 에피소드 시작 : ep = 92, 초기 상태 = [10. 50.  0.  1.]
# Run 0 에피소드 종료 : ep = 92, 총 보상 = -32.61239109393414, 평균 편차 = 17.0476179741323, 종료상태 = [56.3296     -0.44536242 -1.5752916   1.        ]
# Run 0 에피소드 시작 : ep = 93, 초기 상태 = [10. 50.  0.  1.]
# Run 0 에피소드 종료 : ep = 93, 총 보상 = -49.7475482658831, 평균 편차 = 20.685196608869415, 종료상태 = [35.24728    -0.84098023 -1.715517    1.        ]
# Run 0 에피소드 시작 : ep = 94, 초기 상태 = [10. 50.  0.  1.]
# Run 0 에피소드 종료 : ep = 94, 총 보상 = -19.519416539261172, 평균 편차 = 22.92766190154685, 종료상태 = [90.887825   49.384415    0.11167598  1.        ]
# Run 0 에피소드 시작 : ep = 95, 초기 상태 = [10. 50.  0.  1.]
# Run 0 에피소드 종료 : ep = 95, 총 보상 = 34.50982670929826, 평균 편차 = 16.49962166696787, 종료상태 = [90.84886   64.37873    0.2904005  1.       ]
# Run 0 에피소드 시작 : ep = 96, 초기 상태 = [10. 50.  0.  1.]
# Run 0 에피소드 종료 : ep = 96, 총 보상 = -57.51326231638897, 평균 편차 = 22.145552397123538, 종료상태 = [23.364607  -0.5719665 -0.7012048  1.       ]
# Run 0 에피소드 시작 : ep = 97, 초기 상태 = [10. 50.  0.  1.]
# Run 0 에피소드 종료 : ep = 97, 총 보상 = 19.826576638038084, 평균 편차 = 17.605008827315437, 종료상태 = [90.408226   79.57593     0.12532234  1.        ]
# Run 0 에피소드 시작 : ep = 98, 초기 상태 = [10. 50.  0.  1.]
# Run 0 에피소드 종료 : ep = 98, 총 보상 = -38.23137880133892, 평균 편차 = 18.29178015667459, 종료상태 = [ 86.495155 100.20187    1.059653   1.      ]
# Run 0 에피소드 시작 : ep = 99, 초기 상태 = [10. 50.  0.  1.]
# Run 0 에피소드 종료 : ep = 99, 총 보상 = -34.245022396143504, 평균 편차 = 17.211402753504313, 종료상태 = [ 51.823692  100.285706    2.0149772   1.       ]

# %%
# 시각화
# “성공률” 체크하는 간단 지표 : 성공 여부는 "ep 끝에서 x>90"로 판정
# 이 그래프가 우상향하고, 성공률이 70%+로 올라가면 “안정”으로 봐도 좋다.
success_flags = [traj_end[0] > 90 for _, traj in run_trajectories for traj_end in [traj[-1]]]
success_rate = sum(success_flags) / len(success_flags)
print(f"Success rate: {success_rate*100:.1f}%")

# 이동 평균 보상(예: 20-ep window)
def moving_avg(a, w=20):
    return np.convolve(a, np.ones(w)/w, mode='valid')

w = 20
ma = moving_avg(reward_history, w)
episodes = np.arange(w-1, w-1 + len(ma))  # 에피소드 번호 정렬

plt.figure(figsize=(6,3))
plt.plot(episodes, ma, label=f"Moving Avg (w={w})")
plt.title("Moving Avg Reward (window=20)")
plt.xlabel("Episode")
plt.ylabel("Reward (moving average)")
plt.grid(True, alpha=0.3)
plt.legend()
plt.tight_layout()
plt.show()
"""
이 그래프는 매우 만족스러운 학습 결과를 보여주는 전형적인 DQN 패턴이다.
"""
# Out:
# Success rate: 0.0%

# %%
# 편차(Deviation) 이동평균 그래프 → 중앙선을 얼마나 잘 유지하는지 시각적으로 확인 가능.
plt.plot(moving_avg(deviation_history, 20))
plt.title("Moving Avg Deviation (lower=better)")
plt.xlabel("Episode")
plt.ylabel("Mean deviation (|y-50|)")
plt.show()

# %%
# 평균 시계열 분석 시각화
# 여러 번의 run을 평균낸 값을 기반으로, 에피소드마다의 보상 변화 추세를 시각화

# 평균 보상 / 평균 편차 계산
# all_run_rewards: 각 run의 reward 기록들 → 2차원 리스트
# (예: [[run0의 100개 보상], [run1의 100개 보상], ...])
mean_rewards = np.mean(all_run_rewards, axis=0)  # axis=0: 같은 에피소드끼리 평균을 냄
mean_deviations = np.mean(all_run_deviations, axis=0)

fig, ax1 = plt.subplots(figsize=(10, 4))
# ax1은 첫 번째 Y축을 가진 좌표축 객체
ax1.plot(mean_rewards, label="Average Total Reward", color='green', marker='x')
ax1.set_ylabel("Total Reward", color='green')
ax1.set_xlabel("Episode")
ax1.tick_params(axis='y', labelcolor='green')  # 왼쪽 Y축 눈금 글자도 초록색으로 맞춤
ax1.grid(True)

# 보상 그래프에 더해서, 도로 중심선(y=50)에서의 평균 편차도 함께 보여주는 이중 Y축 그래프
ax2 = ax1.twinx()   # ax1과 같은 X축을 공유하는 두 번째 Y축을 생성
# 왼쪽 Y축은 보상(total reward), 오른쪽 Y축은 중심선 편차(y deviation)

ax2.plot(mean_deviations, label="Average Y Deviation", color='blue', marker='o')
ax2.set_ylabel("Deviation from Y=50", color='blue')
ax2.tick_params(axis='y', labelcolor='blue')
fig.suptitle("Average Reward and Y Deviation over Multiple Runs")  # 그래프 전체 제목
fig.tight_layout()
fig.savefig("aver_reward_devi.png")   # 이미지 파일로 저장

# 에피소드 단위로 시계열 분석 - 두 가지 지표를 동시에 시각화했다.
# 즉, 여러 번의 학습(Run)을 통해 얻은 평균 보상과 도로 중심선(Y=50)으로부터의 편차를 에피소드마다 시각화한 것.
# 1) 왼쪽 Y축 (녹색 선): Total Reward : 각 에피소드에서 얻은 총 보상의 평균.
#     보상 증가는 학습이 잘 되고 있음을 의미한다.
#     0 이상이면 좋은 성과, 0 이하면 도로 밖으로 벗어나는 등의 패널티가 많았음을 의미.
# 2) 오른쪽 Y축 (파란 선): Deviation from Y=50
#    도로의 중앙선(Y=50) 으로부터 얼마나 벗어났는지를 나타내는 편차.
#    이 값이 작을수록 → 차가 중심선을 잘 따라감 (좋음),  클수록 → 도로에서 많이 벗어남 (나쁨)
# 3) X축 (Episode) : 0부터 99까지 총 100개 에피소드 동안의 학습 경과를 보여줌

# %%
# 에피소드 번호가 80보다 큰 것만 골라서,각 에피소드마다 색을 다르게 지정해 애니메이션하기 준비
import matplotlib.cm as cm   # 컬러맵(color map) 모듈(색상 그라데이션, 여러 선 서로 다른 색 지정)

# 에피소드(ep) 번호가 80 이상인 궤적만 필터링. final_trajectories: 전체 에피소드의 주행 경로 목록
filtered = [(ep, traj) for ep, traj in final_trajectories if ep > 80]

# 리스트를 dict로 변환. 키: 에피소드 번호, 값: 그 에피소드의 주행 경로
filtered_traj_by_episode = {ep: traj for ep, traj in filtered}
# 애니메이션에서 순서를 유지하기 위해 에피소드 번호를 정렬
eps = sorted(filtered_traj_by_episode.keys())

# 에피소드마다 색 지정 (점점 파래지도록)
cmap = cm.get_cmap("Blues", len(eps))  # "Blues"는 Matplotlib 지원 파란색 계열 그라데이션 컬러맵
# get_cmap("Blues", N)은 총 N개의 다른 농도의 파란색을 만든다

colors = [cmap(i) for i in range(len(eps))]  # colors는 에피소드마다 다른 파란색을 할당한 리스트

# 애니메이션 플롯 설정
fig, ax = plt.subplots(figsize=(6, 6))     # ax: 실제 그래프가 그려지는 좌표축 객체 (axes)
ax.set_xlim(0, 100)             # 도로 크기와 일치하도록 X축, Y축 범위를 0~100으로 설정
ax.set_ylim(0, 100)             # 미니카가 주행하는 공간의 실제 위치와 일치시킴
ax.set_title("MiniCar RL Trajectory Animation (Ep > 80)")
ax.axvline(50, color='lightgray', linestyle='--')    # 도로 중심선 시각화
ax.axhline(50, color='lightgray', linestyle='--')

# 배경 영역 표시(도로 표현) (0,0)부터 (100,100)까지의 사각형 영역에 회색 배경 추가
ax.add_patch(Rectangle((0, 0), 100, 100, linewidth=1, edgecolor='gray', facecolor='#f0f0f0', alpha=0.3))
text = ax.text(5, 95, '', fontsize=10)    # 텍스트 객체 생성 (Step 표시용)

# 각 에피소드마다 선 객체 미리 생성
lines = []   # lines 리스트에 저장하여 에피소드별 궤적을 각각 담당
for color in colors:
    # ax.plot([], []) → 비어 있는 선 그래프 하나 생성 (초기 상태)
    line, = ax.plot([], [], linestyle='--', color=color, linewidth=1)
    lines.append(line)

# 초기화 함수 : FuncAnimation의 init_func에 사용
# 애니메이션 시작 시: 모든 선(line)을 비움, 텍스트도 초기화. 항상 비어 있는 상태로부터 시작
def init():
    for line in lines:
        line.set_data([], [])
    text.set_text('')
    return lines + [text]

# 업데이트 함수 - 프레임마다 궤적 그리는 함수
def update(frame):
    for idx, ep in enumerate(eps):              # 각 에피소드별로 궤적 업데이트
        traj = filtered_traj_by_episode[ep]    # 해당 에피소드의 궤적
        if frame < len(traj):
            path = np.array(traj[:frame+1])    # 현재 frame까지의 경로
            lines[idx].set_data(path[:, 0], path[:, 1])  # (x, y)
    text.set_text(f"Step {frame}")              # 현재 step 번호 표시
    return lines + [text]
# 주요 동작 : frame 값은 0부터 증가하며 애니메이션의 시간축 역할
# 각 에피소드에 대해 : 궤적이 frame보다 길면 해당 시점까지의 경로를 set_data()로 업데이트
# 선이 점점 길어지며 자동 주행 궤적이 그려지는 효과 발생
# 텍스트에 현재 step 표시

# 프레임 수 계산: 프레임 수는 가장 긴 궤적 길이
# filtered_traj_by_episode는 ep > 80인 에피소드들의 주행 궤적 딕셔너리
# 각각의 궤적(traj)은 (x, y, theta, v) 상태 리스트로 이루어진 경로
max_len = max(len(traj) for traj in filtered_traj_by_episode.values())
# 가장 긴 궤적의 길이를 계산하여 → 애니메이션의 전체 프레임 수로 사용
# 예: ep 85의 궤적 길이 = 100, ep 92의 궤적 길이 = 115, ep 97의 궤적 길이 = 123
# max_len = 123 → 애니메이션은 총 123프레임으로 구성

# 애니메이션 생성
ani = animation.FuncAnimation(fig, update, frames=max_len, init_func=init, interval=50, blit=True)
# update : 매 프레임마다 호출할 함수
# frames=max_len : 총 프레임 수 (0부터 max_len - 1까지 반복)
# init_func=init : 애니메이션 시작 전에 한 번만 호출될 초기화 함수
# interval=50 : 프레임 간 시간 간격 (50ms → 초당 약 20프레임 느낌)
# blit=True   : 효율적으로 화면 일부만 업데이트 (성능 향상)

# Colab에서 HTML5 비디오로 애니메이션 출력
from IPython.display import HTML
# HTML(ani.to_jshtml())     또는
HTML(ani.to_html5_video())  # 둘 중 아무거나 사용 가능.

ani.save("minicarani_blue.mp4", fps=10, dpi=150)
# fps=10 → 초당 10프레임, dpi=150 → 해상도 설정 (Dots Per Inch)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2081/3316205525.py in <cell line: 0>()
#       3
#       4 # 에피소드(ep) 번호가 80 이상인 궤적만 필터링. final_trajectories: 전체 에피소드의 주행 경로 목록
# ----> 5 filtered = [(ep, traj) for ep, traj in final_trajectories if ep > 80]
#       6
#       7 # 리스트를 dict로 변환. 키: 에피소드 번호, 값: 그 에피소드의 주행 경로
#
# NameError: name 'final_trajectories' is not defined
